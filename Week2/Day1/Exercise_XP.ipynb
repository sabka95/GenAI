# %% [markdown]
# 🌟Exercise 1: Introduction to Data Analysis (Easy)

# %%
# Objective: Understand the basic overview and significance of data analysis.
# Task:
# Write a short essay or report on the following topics:

# What is data analysis?
# Why is data analysis important in modern contexts?
# List and describe three areas where data analysis is applied today.

# %% [markdown]
# data analysis, the process of systematically collecting, cleaning, transforming, describing, modeling, and interpreting data, generally employing statistical techniques.
# data from multiple sources can reveal new insights and patterns, highlighting areas of opportunity. Businesses may discover niche markets to target, needs to fulfill, or ways to expand into new products and services. Data analysis is crucial for innovation and staying ahead of competitors.
# 1.Healthcare: Predicts diseases and improves treatments using patient data.
# 2.Finance: Detects fraud and assesses credit risk through transaction analysis.
# 3.Retail: Analyzes customer behavior for personalized marketing and inventory control.

# %% [markdown]
# 🌟Exercise 2: Dataset Loading and Initial Analysis

# %%
# Objective: Practice dataset loading from Kaggle and initial analysis.
# Task:
# for the following dataset : How Much Sleep Do Americans Really Get?, Global Trends in Mental Health Disorder and Credit Card Approvals.

# Load the dataset into Jupyter or Google Colab.
# Display the first few rows.
# Provide a brief dataset description.

# %%
import pandas as pd

mental_health_df = pd.read_csv('/content/Mental health Depression disorder Data.csv')
time_americans_df = pd.read_csv('/content/Time Americans Spend Sleeping.csv')
clean_data_df = pd.read_csv('/content/clean_dataset.csv')
# Out:
# <ipython-input-13-ce92edf2dc78>:3: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   mental_health_df = pd.read_csv('/content/Mental health Depression disorder Data.csv')

# %%
mental_health_df.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %%
mental_health_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108553 entries, 0 to 108552
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   index                      108553 non-null  int64
#  1   Entity                     108553 non-null  object
#  2   Code                       103141 non-null  object
#  3   Year                       108553 non-null  object
#  4   Schizophrenia (%)          25875 non-null   object
#  5   Bipolar disorder (%)       19406 non-null   object
#  6   Eating disorders (%)       100236 non-null  object
#  7   Anxiety disorders (%)      6468 non-null    float64
#  8   Drug use disorders (%)     6468 non-null    float64
#  9   Depression (%)             6468 non-null    float64
#  10  Alcohol use disorders (%)  6468 non-null    float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 9.1+ MB

# %%
time_americans_df.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
time_americans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB

# %%
clean_data_df.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %%
clean_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB

# %% [markdown]
# 🌟Exercise 3: Identifying Data Types

# %%
# Objective: Learn to identify different data types.
# Task:
# For the datasets from the previous exercise, categorize each column of it as either quantitative or qualitative and explain your reasoning.

# %% [markdown]
# Mental health Depression disorder Data :
#
# Les données suivantes sont quantitatives car elles représentent des valeurs numériques :
#
# Anxiety disorders, Drug use disorders, Depression, Alcohol use disorders
#
#
# Les données suivantes sont qualitatives car elles représentent des catégories ou des classes :
#
# Entity, Code, Year, Schizophrenia, Bipolar disorder, Eating disorders

# %% [markdown]
# Time Americans Spend Sleeping :
#
# Les données suivantes sont quantitatives car elles représentent des valeurs numériques :
#
#  Year, Avg hrs per day sleeping, Standard Error
#
# Les données suivantes sont qualitatives car elles représentent des catégories ou des classes :
#
#  Period, Type of Days, Age Group, Activity, Sex

# %% [markdown]
# clean_dataset :
#
# Les données suivantes sont quantitatives car elles représentent des valeurs numériques :
#
# Gender, Age, Debt, Married, BankCustomer, YearsEmployed, PriorDefault, Employed, CreditScore, DriversLicense, ZipCode, Income, Approved
#
#
# Les données suivantes sont qualitatives car elles représentent des catégories ou des classes :
#
# Industry, Ethnicity, Citizen

# %% [markdown]
# 🌟Exercise 4: Exploring Data Types

# %%
# Objective: Learn about different types of data in data analysis.
# Task:
# Load the Iris dataset using Kaggle into a Jupyter Notebook or Google Colaboratory Notebook.
# Identify and list which columns in your dataset are qualitative and which are quantitative.
# Write a brief description of why each column is classified as qualitative or quantitative.

# %%
iris_df = pd.read_csv("/content/Iris.csv")

# %%
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# Iris :
#
# Les données suivantes sont quantitatives car elles représentent des valeurs numériques :
#
# Id, Drug use SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm
#
#
# Les données suivantes sont qualitatives car elles représentent des catégories ou des classes :
#
# Species

# %% [markdown]
# 🌟Exercise 5: Basic Data Analysis with Google Colab

# %%
# Objective: Perform basic data analysis using Google Colab.
# Task:
# Using the same notebook from the previous exercise, perform basic data analysis tasks:
# Calculate the mean, median, and mode of a quantitative column.
# Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries

# %%
iris_df["SepalLengthCm"].mean()
# Out:
# 5.843333333333334

# %%
iris_df["SepalLengthCm"].median()
# Out:
# 5.8

# %%
iris_df["SepalLengthCm"].mode()
# Out:
# 0    5.0
# Name: SepalLengthCm, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.plot(iris_df["Id"], iris_df['SepalLengthCm'], iris_df['SepalWidthCm'])
plt.show()

# %% [markdown]
# 🌟Exercise 6: Basic Observation Skills in Data Analysis

# %%
# Objective: Develop observation skills for data analysis.
# Task:
# Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.
# Identify columns that could be interesting for a specific type of analysis (e.g., trend analysis, group comparison) and explain your choice.
# Tools: Jupyter Notebook, Python with Pandas library.

# %%
time_americans_df.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %% [markdown]
# trend analysis :
#
# For trend analysis : comparere Year against Avg hrs per day sleeping. In order to dertermine what could influence the sleepling time in the US.
# For group comparison : Use the Sex or Age against Avg hrs per day sleeping. In order to the difference between populations.
