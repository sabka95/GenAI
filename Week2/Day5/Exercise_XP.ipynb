# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

superstore_file = pd.read_excel("/content/drive/MyDrive/GENAI/Week2/Day5/US Superstore data.xls")
df_superstore = pd.DataFrame(superstore_file)
df_superstore.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df_superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7143 entries, 0 to 9992
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         7143 non-null   int64
#  1   Order ID       7143 non-null   object
#  2   Order Date     7143 non-null   datetime64[ns]
#  3   Ship Date      7143 non-null   datetime64[ns]
#  4   Ship Mode      7143 non-null   object
#  5   Customer ID    7143 non-null   object
#  6   Customer Name  7143 non-null   object
#  7   Segment        7143 non-null   object
#  8   Country        7143 non-null   object
#  9   City           7143 non-null   object
#  10  State          7143 non-null   object
#  11  Postal Code    7143 non-null   int64
#  12  Region         7143 non-null   object
#  13  Product ID     7143 non-null   object
#  14  Category       7143 non-null   object
#  15  Sub-Category   7143 non-null   object
#  16  Product Name   7143 non-null   object
#  17  Sales          7143 non-null   float64
#  18  Quantity       7143 non-null   int64
#  19  Discount       7143 non-null   float64
#  20  Profit         7143 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.2+ MB

# %%
df_superstore.drop_duplicates(inplace=True)

# %%
columns = df_superstore.select_dtypes(include='number').columns

outliers = pd.DataFrame()

for col in columns:
  Q1 = df_superstore[col].quantile(0.25)
  Q3 = df_superstore[col].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  outlier = df_superstore[(df_superstore[col] < lower_bound) | (df_superstore[col] > upper_bound)]
  outlier['outliers'] = col
  outliers = pd.concat([outliers, outlier])

outliers.drop_duplicates(inplace=True)
outliers
# Out:
# /tmp/ipython-input-4-2389085306.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outlier['outliers'] = col
# /tmp/ipython-input-4-2389085306.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outlier['outliers'] = col
# /tmp/ipython-input-4-2389085306.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outlier['outliers'] = col
# /tmp/ipython-input-4-2389085306.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outlier['outliers'] = col
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10        11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 11        12  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9957    9958  US-2014-143287 2014-11-11 2014-11-17  Standard Class
# 9962    9963  CA-2015-168088 2015-03-19 2015-03-22     First Class
# 9968    9969  CA-2017-153871 2017-12-11 2017-12-17  Standard Class
# 9979    9980  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 1       CG-12520       Claire Gute     Consumer  United States
# 3       SO-20335    Sean O'Donnell     Consumer  United States
# 7       BH-11710   Brosina Hoffman     Consumer  United States
# 10      BH-11710   Brosina Hoffman     Consumer  United States
# 11      BH-11710   Brosina Hoffman     Consumer  United States
# ...          ...               ...          ...            ...
# 9957    KN-16705     Kristina Nunn  Home Office  United States
# 9962    CM-12655  Corinna Mitchell  Home Office  United States
# 9968    RB-19435   Richard Bierner     Consumer  United States
# 9979    AP-10720        Anne Pryor  Home Office  United States
# 9993    CC-12220      Chris Cortes     Consumer  United States
#
#                  City  ...   Region       Product ID         Category  \
# 1           Henderson  ...    South  FUR-CH-10000454        Furniture
# 3     Fort Lauderdale  ...    South  FUR-TA-10000577        Furniture
# 7         Los Angeles  ...     West  TEC-PH-10002275       Technology
# 10        Los Angeles  ...     West  FUR-TA-10001539        Furniture
# 11        Los Angeles  ...     West  TEC-PH-10002033       Technology
# ...               ...  ...      ...              ...              ...
# 9957     New Rochelle  ...     East  OFF-PA-10004039  Office Supplies
# 9962          Houston  ...  Central  FUR-BO-10004218        Furniture
# 9968       Plainfield  ...     East  OFF-BI-10004600  Office Supplies
# 9979      Los Angeles  ...     West  OFF-BI-10002026  Office Supplies
# 9993      Westminster  ...     West  OFF-AP-10002684  Office Supplies
#
#      Sub-Category                                       Product Name  \
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table
# 7          Phones                     Mitel 5320 IP Phone VoIP phone
# 10         Tables           Chromcraft Rectangular Conference Tables
# 11         Phones      Konftel 250 Conference phone - Charcoal black
# ...           ...                                                ...
# 9957        Paper                                         Xerox 1882
# 9962    Bookcases  Bush Heritage Pine Collection 5-Shelf Bookcase...
# 9968      Binders          Ibico Ibimaster 300 Manual Binding System
# 9979      Binders                  Ibico Recycled Linen-Style Covers
# 9993   Appliances  Acco 7-Outlet Masterpiece Power Center, Wihtou...
#
#           Sales Quantity  Discount    Profit  outliers
# 1      731.9400        3      0.00  219.5820     Sales
# 3      957.5775        5      0.45 -383.0310     Sales
# 7      907.1520        6      0.20   90.7152     Sales
# 10    1706.1840        9      0.20   85.3092     Sales
# 11     911.4240        4      0.20   68.3568     Sales
# ...         ...      ...       ...       ...       ...
# 9957   223.9200        4      0.00  109.7208    Profit
# 9962   383.4656        4      0.32  -67.6704    Profit
# 9968   735.9800        2      0.00  331.1910    Profit
# 9979   437.4720       14      0.20  153.1152    Profit
# 9993   243.1600        2      0.00   72.9480    Profit
#
# [4074 rows x 22 columns]

# %%
df_superstore.drop(outliers.index, inplace = True)
df_superstore.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
# 5       90032    West  FUR-FU-10001487        Furniture  Furnishings
# 6       90032    West  OFF-AR-10002833  Office Supplies          Art
#
#                                         Product Name    Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.960         2
# 2  Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 4                     Eldon Fold 'N Roll Cart System   22.368         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 6                                         Newell 322    7.280         4
#
#    Discount   Profit
# 0       0.0  41.9136
# 2       0.0   6.8714
# 4       0.2   2.5164
# 5       0.0  14.1694
# 6       0.0   1.9656
#
# [5 rows x 21 columns]

# %%
df_superstore_cleaned = df_superstore.copy()

# %%
df_superstore_reduced = df_superstore_cleaned.drop(["Order ID", "Customer ID", "Product ID"], axis = 1)
df_superstore_reduced.head()
# Out:
#    Row ID Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 0       1 2016-11-08 2016-11-11    Second Class      Claire Gute   Consumer
# 2       3 2016-06-12 2016-06-16    Second Class  Darrin Van Huff  Corporate
# 4       5 2015-10-11 2015-10-18  Standard Class   Sean O'Donnell   Consumer
# 5       6 2014-06-09 2014-06-14  Standard Class  Brosina Hoffman   Consumer
# 6       7 2014-06-09 2014-06-14  Standard Class  Brosina Hoffman   Consumer
#
#          Country             City       State  Postal Code Region  \
# 0  United States        Henderson    Kentucky        42420  South
# 2  United States      Los Angeles  California        90036   West
# 4  United States  Fort Lauderdale     Florida        33311  South
# 5  United States      Los Angeles  California        90032   West
# 6  United States      Los Angeles  California        90032   West
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 2  Office Supplies       Labels
# 4  Office Supplies      Storage
# 5        Furniture  Furnishings
# 6  Office Supplies          Art
#
#                                         Product Name    Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.960         2
# 2  Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 4                     Eldon Fold 'N Roll Cart System   22.368         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 6                                         Newell 322    7.280         4
#
#    Discount   Profit
# 0       0.0  41.9136
# 2       0.0   6.8714
# 4       0.2   2.5164
# 5       0.0  14.1694
# 6       0.0   1.9656

# %%
df_superstore_reduced["Profit Margin"] = (df_superstore_reduced["Profit"] / df_superstore_reduced["Sales"]) * 100
df_superstore_reduced["Order Year"] = df_superstore_reduced["Order Date"].dt.year
df_superstore_reduced["Order Month"] = df_superstore_reduced["Order Date"].dt.month
df_superstore_reduced["Ship Year"] = df_superstore_reduced["Ship Date"].dt.year
df_superstore_reduced["Ship Month"] = df_superstore_reduced["Ship Date"].dt.month

df_superstore_reduced.head()
# Out:
#    Row ID Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 0       1 2016-11-08 2016-11-11    Second Class      Claire Gute   Consumer
# 2       3 2016-06-12 2016-06-16    Second Class  Darrin Van Huff  Corporate
# 4       5 2015-10-11 2015-10-18  Standard Class   Sean O'Donnell   Consumer
# 5       6 2014-06-09 2014-06-14  Standard Class  Brosina Hoffman   Consumer
# 6       7 2014-06-09 2014-06-14  Standard Class  Brosina Hoffman   Consumer
#
#          Country             City       State  Postal Code  ...  \
# 0  United States        Henderson    Kentucky        42420  ...
# 2  United States      Los Angeles  California        90036  ...
# 4  United States  Fort Lauderdale     Florida        33311  ...
# 5  United States      Los Angeles  California        90032  ...
# 6  United States      Los Angeles  California        90032  ...
#
#                                         Product Name    Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.960        2
# 2  Self-Adhesive Address Labels for Typewriters b...   14.620        2
# 4                     Eldon Fold 'N Roll Cart System   22.368        2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.860        7
# 6                                         Newell 322    7.280        4
#
#   Discount   Profit  Profit Margin  Order Year  Order Month  Ship Year  \
# 0      0.0  41.9136          16.00        2016           11       2016
# 2      0.0   6.8714          47.00        2016            6       2016
# 4      0.2   2.5164          11.25        2015           10       2015
# 5      0.0  14.1694          29.00        2014            6       2014
# 6      0.0   1.9656          27.00        2014            6       2014
#
#    Ship Month
# 0          11
# 2           6
# 4          10
# 5           6
# 6           6
#
# [5 rows x 23 columns]

# %%
df = df_superstore_reduced.drop(["Order Date", "Ship Date"], axis = 1)
df.head()
# Out:
#    Row ID       Ship Mode    Customer Name    Segment        Country  \
# 0       1    Second Class      Claire Gute   Consumer  United States
# 2       3    Second Class  Darrin Van Huff  Corporate  United States
# 4       5  Standard Class   Sean O'Donnell   Consumer  United States
# 5       6  Standard Class  Brosina Hoffman   Consumer  United States
# 6       7  Standard Class  Brosina Hoffman   Consumer  United States
#
#               City       State  Postal Code Region         Category  ...  \
# 0        Henderson    Kentucky        42420  South        Furniture  ...
# 2      Los Angeles  California        90036   West  Office Supplies  ...
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies  ...
# 5      Los Angeles  California        90032   West        Furniture  ...
# 6      Los Angeles  California        90032   West  Office Supplies  ...
#
#                                         Product Name    Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.960         2
# 2  Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 4                     Eldon Fold 'N Roll Cart System   22.368         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 6                                         Newell 322    7.280         4
#
#    Discount   Profit  Profit Margin  Order Year  Order Month  Ship Year  \
# 0       0.0  41.9136          16.00        2016           11       2016
# 2       0.0   6.8714          47.00        2016            6       2016
# 4       0.2   2.5164          11.25        2015           10       2015
# 5       0.0  14.1694          29.00        2014            6       2014
# 6       0.0   1.9656          27.00        2014            6       2014
#
#    Ship Month
# 0          11
# 2           6
# 4          10
# 5           6
# 6           6
#
# [5 rows x 21 columns]

# %% [markdown]
# Which states have the most sales?

# %%
most_sales = df.groupby("State")["Sales"].sum().sort_values(ascending = False).head(1)
most_sales
# Out:
# State
# California    130572.2035
# Name: Sales, dtype: float64

# %% [markdown]
# What is the difference between New York and California in terms of sales and profit?

# %%
filtered_df = df[(df["State"] == "New York") | (df["State"] == "California")]
state_sales = filtered_df.groupby("State")[["Sales", "Profit"]].sum()
state_sales
# Out:
#                   Sales      Profit
# State
# California  130572.2035  23229.9930
# New York     61023.7050  13406.5385

# %% [markdown]
# Who is an outstanding customer in New York?

# %%
filtered_df = df[(df["State"] == "New York")]
top_customer = filtered_df.groupby("Customer Name")["Sales"].sum().sort_values(ascending = False).head(1)
top_customer
# Out:
# Customer Name
# Caroline Jumper    1012.81
# Name: Sales, dtype: float64

# %% [markdown]
# Are there any differences among states in profitability?

# %%
import matplotlib.pyplot as plt
import ipywidgets as widgets


category_dropdown = widgets.Dropdown(
    options=df['Category'].unique(),
    description='Category:'
)

def update_chart(selected_category):

    filtered_df = df[df['Category'] == selected_category]

    grouped = filtered_df.groupby('State')['Profit'].sum().reset_index()

    plt.figure(figsize=(10, 6))
    plt.bar(grouped["State"], grouped["Profit"])
    plt.title(f'Sales per state for {selected_category}')
    plt.xlabel('State')
    plt.ylabel('Total Sales')
    plt.xticks(rotation=90)
    plt.legend(title=selected_category)
    plt.show()


widgets.interactive(update_chart, selected_category=category_dropdown)
# Out:
# interactive(children=(Dropdown(description='Category:', options=('Furniture', 'Office Supplies', 'Technology')…

# %% [markdown]
#  Can we apply Pareto principle to customers and Profit ?

# %%
grouped = df.groupby('Customer Name')['Profit'].sum().reset_index()
grouped = grouped.sort_values(by='Profit', ascending=False)
grouped
# Out:
#        Customer Name    Profit
# 160      Chuck Clark  443.1515
# 60    Arthur Prichep  436.8827
# 592       Paul Prost  419.0327
# 385         John Lee  412.8366
# 500     Matt Abelman  406.2710
# ..               ...       ...
# 764   Troy Blackwell  -17.4571
# 536    Mick Crebagga  -17.9051
# 408     Justin Hirsh  -18.0742
# 539  Mike Gockenbach  -18.8184
# 43        Anna Chung  -28.7004
#
# [787 rows x 2 columns]

# %%
grouped.reset_index(drop=True, inplace=True)

# %%
import numpy as np

n_customer = grouped.shape[0]
total_sales = grouped['Profit'].sum()

grouped['cum_Profit'] = grouped["Profit"].cumsum()
grouped['cum_Pofit_%'] = grouped['cum_Profit']/total_sales * 100
grouped["customer_%"] =(grouped.index + 1)/n_customer * 100
grouped
# Out:
#        Customer Name    Profit  cum_Profit  cum_Pofit_%  customer_%
# 160      Chuck Clark  443.1515    443.1515     0.477166   20.457433
# 60    Arthur Prichep  436.8827    880.0342     0.947582    7.750953
# 592       Paul Prost  419.0327   1299.0669     1.398779   75.349428
# 385         John Lee  412.8366   1711.9035     1.843303   49.047014
# 500     Matt Abelman  406.2710   2118.1745     2.280758   63.659466
# ..               ...       ...         ...          ...         ...
# 764   Troy Blackwell  -17.4571  92955.0128   100.089907   97.204574
# 536    Mick Crebagga  -17.9051  92937.1077   100.070628   68.233799
# 408     Justin Hirsh  -18.0742  92919.0335   100.051166   51.969504
# 539  Mike Gockenbach  -18.8184  92900.2151   100.030903   68.614994
# 43        Anna Chung  -28.7004  92871.5147   100.000000    5.590851
#
# [787 rows x 5 columns]

# %%
grouped = grouped[grouped['cum_Pofit_%'] >= 80].head(1)
grouped
# Out:
#     Customer Name   Profit  cum_Profit  cum_Pofit_%  customer_%
# 322   Heather Jas  98.6548  74321.8373    80.026516   41.041931

# %% [markdown]
# No, 20% of customers do not contribute to 80% of the profit

# %% [markdown]
# What are the Top 20 cities by Sales ?

# %%
grouped = df.groupby('City')['Sales'].sum().reset_index().sort_values(by = 'Sales', ascending=False).head(20)
grouped.reset_index(drop=True, inplace=True)
grouped
# Out:
#              City       Sales
# 0     Los Angeles  52122.8965
# 1   New York City  50847.3030
# 2         Seattle  28177.3760
# 3   San Francisco  26637.5340
# 4    Philadelphia  22730.3030
# 5         Houston  16378.4726
# 6       San Diego  12138.0880
# 7         Chicago  12042.6350
# 8        Columbus  10588.0100
# 9          Dallas   9086.9736
# 10    Springfield   8877.7960
# 11        Detroit   8030.4120
# 12       Columbia   5588.6180
# 13         Newark   5400.1580
# 14   Jacksonville   5174.9920
# 15       Richmond   4884.0100
# 16    San Antonio   4160.7950
# 17        Jackson   3666.8370
# 18        Phoenix   3448.6850
# 19         Aurora   3408.5020

# %%
grouped2 = df.groupby('City')['Profit'].sum().reset_index().sort_values(by = 'Profit', ascending=False).head(20)
grouped2.reset_index(drop=True, inplace=True)
grouped2
# Out:
#              City      Profit
# 0   New York City  10922.1115
# 1     Los Angeles   8659.3129
# 2   San Francisco   5606.3066
# 3         Seattle   5274.7966
# 4       San Diego   2118.2453
# 5         Houston   1931.3872
# 6         Detroit   1889.8525
# 7        Columbus   1861.5010
# 8     Springfield   1751.5902
# 9        Richmond   1338.1226
# 10         Newark   1189.5637
# 11       Columbia   1111.6406
# 12   Philadelphia   1107.0865
# 13        Jackson   1039.8102
# 14        Chicago    912.6978
# 15     Louisville    677.8366
# 16         Dallas    671.5388
# 17   Jacksonville    670.2140
# 18      Henderson    664.8372
# 19      Baltimore    627.2632

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, (ax1, ax2) = plt.subplots(2,1, figsize=(10,9))
ax1.scatter(x = 'City', y = 'Sales', data = grouped)
ax1.set_title('Sales by City')
ax1.tick_params(rotation=90)
ax2.scatter(x = 'City', y = 'Profit', data = grouped2)
ax2.set_title('Profit by City')
ax2.tick_params(rotation=90)
plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# These plots show that although Los Angeles generates the highest sales, it ranks only second in terms of profit, behind New York City. This pattern is observed in several other cities as well, where higher sales do not necessarily translate into higher profits — likely due to lower profit margins.

# %% [markdown]
# What are the Top 20 customers by Sales?

# %%
most_sales = df.groupby("Customer Name")["Sales"].sum().sort_values(ascending = False).head(20)
most_sales
# Out:
# Customer Name
# Paul Prost           2767.4700
# William Brown        2477.9180
# Joel Eaton           2441.4610
# Arthur Gainer        2211.2510
# Fred McMath          2158.7780
# Adrian Barton        2146.6160
# Chuck Clark          2134.7220
# Sally Hughsby        2078.7835
# Kunst Miller         2056.3260
# Sanjit Chand         2038.7240
# John Lee             1927.2980
# John Castell         1870.8710
# Laura Armstrong      1861.9440
# Dan Reichenbach      1837.3860
# Steve Nguyen         1829.1160
# Lena Cacioppo        1821.6040
# Valerie Dominguez    1769.1940
# Xylona Preis         1768.8080
# Zuschuss Carroll     1762.1920
# Jay Kimmel           1752.4820
# Name: Sales, dtype: float64

# %% [markdown]
# Plot the Cumulative curve in Sales by Customers. Can we apply Pareto principle to customers and Sales ?

# %%
plt.plot(most_sales)
plt.title('Cumulative curve in Sales by Customers')
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.xticks(rotation=90)
plt.show()

# %%
grouped = df.groupby('Customer Name')['Sales'].sum().reset_index()
grouped = grouped.sort_values(by='Sales', ascending=False)
grouped
# Out:
#        Customer Name     Sales
# 592       Paul Prost  2767.470
# 781    William Brown  2477.918
# 379       Joel Eaton  2441.461
# 59     Arthur Gainer  2211.251
# 290      Fred McMath  2158.778
# ..               ...       ...
# 616     Ralph Ritter    17.748
# 123     Carl Jackson    16.520
# 375      Jim Radford    14.040
# 543  Mitch Gastineau    12.320
# 453     Lela Donovan     5.304
#
# [787 rows x 2 columns]

# %%
grouped.reset_index(drop=True, inplace=True)

# %%
n_customer = grouped.shape[0]
total_sales = grouped['Sales'].sum()

grouped['cum_sales'] = grouped["Sales"].cumsum()
grouped['cum_sales_%'] = grouped['cum_sales']/total_sales * 100
grouped["customer_%"] =(grouped.index + 1)/n_customer * 100
grouped
# Out:
#        Customer Name     Sales    cum_sales  cum_sales_%  customer_%
# 0         Paul Prost  2767.470    2767.4700     0.511758    0.127065
# 1      William Brown  2477.918    5245.3880     0.969972    0.254130
# 2         Joel Eaton  2441.461    7686.8490     1.421444    0.381194
# 3      Arthur Gainer  2211.251    9898.1000     1.830347    0.508259
# 4        Fred McMath  2158.778   12056.8780     2.229546    0.635324
# ..               ...       ...          ...          ...         ...
# 782     Ralph Ritter    17.748  540729.1267    99.991090   99.491741
# 783     Carl Jackson    16.520  540745.6467    99.994145   99.618806
# 784      Jim Radford    14.040  540759.6867    99.996741   99.745870
# 785  Mitch Gastineau    12.320  540772.0067    99.999019   99.872935
# 786     Lela Donovan     5.304  540777.3107   100.000000  100.000000
#
# [787 rows x 5 columns]

# %%
grouped = grouped[grouped['cum_sales_%'] >= 80].head(1)
grouped
# Out:
#      Customer Name    Sales    cum_sales  cum_sales_%  customer_%
# 430  Dianna Wilson  552.196  433073.2251    80.083468    54.76493

# %% [markdown]
# No, 20% of customers do not contribute to 80% of the sales

# %% [markdown]
# Based on the analysis, make decisions on which states and cities to prioritize for marketing strategies.

# %% [markdown]
# According to the analysis, it would be more effective from a marketing perspective to focus on New York, Los Angeles, San Francisco, and Seattle, as these cities generate the highest sales and profits.
