# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 🌟 Exercise 1: Understanding Data Visualization

# %% [markdown]
# Data visualization is important in data
# analysis because it makes complex data easier to understand, reveals hidden patterns and trends, and helps communicate insights clearly. It supports better decision-making and engages both technical and non-technical audiences effectively.

# %% [markdown]
# A line graph is used in data visualization to show trends or changes over time. It connects data points with lines, making it easy to observe patterns, increases, or decreases across a continuous variable, such as days, months, or years.

# %% [markdown]
# 🌟 Exercise 2: Creating a Line Plot for Temperature Variation

# %%
import matplotlib.pyplot as plt

week = [72, 74, 76, 80, 82, 78, 75]
Days = ["Lundi", "Mardi", "Mercredi", "Jeudi", "Vendredi", "Samedi", "Dimanche"]

fig = plt.figure(figsize =(10, 10))
plt.title('Temperature Variation')
plt.xlabel("Day")
plt.ylabel("Temperature (°F)")
plt.plot(Days, week)

# %% [markdown]
# 🌟 Exercise 3: Visualizing Monthly Sales with a Bar Chart

# %%
month_sales = [5000, 5500, 6200, 7000, 7500, 6500, 6800, 5900, 4000, 5700, 9000, 8300]
monthes = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

fig = plt.bar(monthes, month_sales)
plt.xlabel("Month")
plt.ylabel("Sales Amount ($)")
plt.title("Monthly sales")
plt.show()

# %% [markdown]
# 🌟 Exercise 4: Visualizing the Distribution of CGPA

# %%
# !unzip "/content/drive/MyDrive/GENAI/Week2/Day4/student's CGPA.zip"
# Out:
# Archive:  /content/drive/MyDrive/GENAI/Week2/Day4/student's CGPA.zip
# replace student_clustering.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
import seaborn as sns
import pandas as pd

student_file = pd.read_csv("/content/student_clustering.csv")
df = pd.DataFrame(student_file)
df
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
sns.histplot(data = df, x = "cgpa", color = "green")
plt.title("student's CGPA")
plt.show()

# %% [markdown]
# 🌟 Exercise 5: Comparing Anxiety Levels Across Different Genders

# %%
# !unzip "/content/drive/MyDrive/GENAI/Week2/Day4/student mental health.zip"
# Out:
# Archive:  /content/drive/MyDrive/GENAI/Week2/Day4/student mental health.zip
# replace Student Mental health.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
mental_health_file = pd.read_csv("/content/Student Mental health.csv")
df = pd.DataFrame(mental_health_file)
df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
df_test = df.groupby("Choose your gender").agg({"Do you have Anxiety?" : "count"})
df_test
# Out:
#                     Do you have Anxiety?
# Choose your gender
# Female                                75
# Male                                  26

# %%
sns.barplot(data = df_test, x = "Choose your gender", y= "Do you have Anxiety?")
plt.title("Anxiety Levels Across Different Genders")
plt.xlabel("Gender")
plt.ylabel("Anxiety")
plt.show()

# %% [markdown]
# 🌟 Exercise 6: Exploring the Relationship Between Age and Panic Attacks

# %%
df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
df.Age.min()
# Out:
# 18.0

# %%
sns.countplot(data = df, x = "Age", hue = "Do you have Panic attack?", color = "green")
plt.title("Age vs Panic Attacks")
plt.xlabel("Age")
plt.ylabel("Panic Attacks")
plt.show()
# Out:
# /tmp/ipython-input-35-958681188.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:green'` for the same effect.
#
#   sns.countplot(data = df, x = "Age", hue = "Do you have Panic attack?", color = "green")

# %% [markdown]
# Le countplot est la méthode de visualisation la plus appropriée pour ce cas ci. Car elle permet de crée un groupe pour chaque réponse et ce pour chaque trache d'âge. Ce qui permet donc de comprendre au premier coup d'oeil la distribution des réponses

# %%
df2 = df.copy()
df2["Do you have Panic attack?"] = df2["Do you have Panic attack?"].map({"Yes" : 1, "No" : 0})
df2.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety?  Do you have Panic attack?  \
# 0                     Yes                   No                          1
# ...
