# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 🌟 Exercise 1 : Matrix Operations

# %%
import numpy as np

# %%
array_2D = np.random.randint(-100,100,size=(3,3))
array_2D
# Out:
# array([[ 22,  52, -26],
#        [-96,   1,  10],
#        [ 78,  66, -69]])

# %%
det = np.linalg.det(array_2D)
det
# Out:
# np.float64(-153161.9999999999)

# %%
inv = np.linalg.inv(array_2D)
inv
# Out:
# array([[ 0.00475967, -0.01222235, -0.00356485],
#        [ 0.03815568, -0.00332981, -0.01486008],
#        [ 0.04187723, -0.01700161, -0.03273658]])

# %% [markdown]
# 🌟 Exercise 2 : Statistical Analysis

# %%
array = np.random.randint(-100,100, size=(1,50))
array
# Out:
# array([[-56,  54,  -8,  88,  73,  10,  79, -35,  43,  88,  31, -93,   9,
#         -30, -44, -15, -64,   0,  23, -76,  17,   9, -51,  42,   6,  66,
#         -59, -18,  81,  33, -40,  76, -79,  33, -17, -23, -31,  49, -32,
#          67, -73,  53, -57, -58,  93,  80, -83, -82,  62,  75]])

# %%
mean = np.mean(array)
mean
# Out:
# np.float64(4.32)

# %%
median = np.median(array)
median
# Out:
# np.float64(7.5)

# %%
std = np.std(array)
std
# Out:
# np.float64(55.93404687665644)

# %% [markdown]
# 🌟 Exercise 3 : Date Manipulation

# %%
dates = np.arange('2023-01-01', '2023-02-01', dtype='datetime64[D]')
dates = np.array([str(date).replace('-', '/') for date in dates])
dates
# Out:
# array(['2023/01/01', '2023/01/02', '2023/01/03', '2023/01/04',
#        '2023/01/05', '2023/01/06', '2023/01/07', '2023/01/08',
#        '2023/01/09', '2023/01/10', '2023/01/11', '2023/01/12',
#        '2023/01/13', '2023/01/14', '2023/01/15', '2023/01/16',
#        '2023/01/17', '2023/01/18', '2023/01/19', '2023/01/20',
#        '2023/01/21', '2023/01/22', '2023/01/23', '2023/01/24',
#        '2023/01/25', '2023/01/26', '2023/01/27', '2023/01/28',
#        '2023/01/29', '2023/01/30', '2023/01/31'], dtype='<U10')

# %% [markdown]
# 🌟 Exercise 4 : Data Manipulation with NumPy and Pandas

# %%
import pandas as pd

# %%
np.random.seed(42)
number = pd.DataFrame(np.random.randint(-100,100, size=(10,10)), columns=list('ABCDEFGHIJ'))
number
# Out:
#     A   B   C   D   E   F   G   H   I   J
# 0   2  79  -8 -86   6 -29  88 -80   2  21
# 1 -26 -13  16  -1   3  51  30  49 -48 -99
# 2 -13  57 -63  29  91  87 -80  60 -43 -79
# 3 -12 -52 -42  69  87 -86  89  89  74  89
# 4 -50   7 -46 -37  30 -50  34 -80 -28  66
# 5 -83  31 -12 -41 -87 -92 -11 -48  29 -17
# 6  -9  10  87  98  71 -93  74 -66 -20  63
# 7 -51   3  31 -99  33 -47   5 -97 -47  90
# 8  45 -57  61  89 -87  -6 -53 -86  99  89
# 9 -61 -19  10 -48 -77  53  87  23 -60  56

# %%
even_index = number.iloc[::2, ::2]
even_index
# Out:
#     A   C   E   G   I
# 0   2  -8   6  88   2
# 2 -13 -63  91 -80 -43
# 4 -50 -46  30  34 -28
# 6  -9  87  71  74 -20
# 8  45  61 -87 -53  99

# %%
sum = number.sum()
sum
# Out:
# A   -258
# B     46
# C     34
# D    -27
# E     70
# F   -212
# G    263
# H   -236
# I    -42
# J    279
# dtype: int64

# %%
mean = number.mean()
mean
# Out:
# A   -25.8
# B     4.6
# C     3.4
# D    -2.7
# E     7.0
# F   -21.2
# G    26.3
# H   -23.6
# I    -4.2
# J    27.9
# dtype: float64

# %% [markdown]
# 🌟 Exercise 5 : Image Representation

# %% [markdown]
# In NumPy, images are represented as multidimensional arrays, where each element corresponds to a pixel value

# %%
import matplotlib.pyplot as plt

# %%
gray_image = np.random.randint(0,255,size=(5,5))

plt.imshow(gray_image, cmap='gray')
plt.title("5x5 Grayscale Image")
plt.colorbar()

# %% [markdown]
# 🌟 Exercise 6 : Basic Hypothesis Testing

# %%
from scipy import stats

np.random.seed(42)

# Productivity scores of employees before the training program
productivity_before = np.random.normal(loc=50, scale=10, size=30)

# Productivity scores of the same employees after the training program
productivity_after = productivity_before + np.random.normal(loc=5, scale=3, size=30)

t_statistic, p_value = stats.ttest_rel(productivity_before, productivity_after)


alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in productivity.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in productivity.")
# Out:
# Reject the null hypothesis. There is a significant difference in productivity.

# %% [markdown]
# 🌟 Exercise 7 : Complex Array Comparison

# %%
array1 = np.random.randint(0,10, size= 10)
print(array1)
array2 = np.random.randint(0, 10, size=10)
print(array2)

difference = array1 > array2
difference
# Out:
# [5 7 8 3 0 0 9 3 6 1]
# [2 0 4 0 7 0 0 1 1 5]
# array([ True,  True,  True,  True, False, False,  True,  True,  True,
#        False])

# %% [markdown]
# 🌟 Exercise 8 : Time Series Data Manipulation

# %%
dates = np.arange('2023-01-01', '2023-12-31', dtype='datetime64[D]')
dates = pd.DataFrame(dates, columns = ["Dates"])
dates
# Out:
#          Dates
# 0   2023-01-01
# 1   2023-01-02
# 2   2023-01-03
# 3   2023-01-04
# 4   2023-01-05
# ..         ...
# 359 2023-12-26
# 360 2023-12-27
# 361 2023-12-28
# 362 2023-12-29
# 363 2023-12-30
#
# [364 rows x 1 columns]

# %%
jan_to_mar = dates[(dates["Dates"] >= '2023-01-01') & (dates["Dates"] <= '2023-03-31')]
apr_to_jun = dates[(dates["Dates"] >= '2023-04-01') & (dates["Dates"] <= '2023-06-30')]
jul_to_sep = dates[(dates["Dates"] >= '2023-07-01') & (dates["Dates"] <= '2023-09-30')]
oct_to_dec = dates[(dates["Dates"] >= '2023-10-01') & (dates["Dates"] <= '2023-12-31')]

# %%
jul_to_sep
# Out:
#          Dates
# 181 2023-07-01
# 182 2023-07-02
# 183 2023-07-03
# 184 2023-07-04
# 185 2023-07-05
# ..         ...
# 268 2023-09-26
# 269 2023-09-27
# 270 2023-09-28
# 271 2023-09-29
# 272 2023-09-30
#
# [92 rows x 1 columns]

# %% [markdown]
# 🌟 Exercise 9 : Data Conversion

# %%
array = np.random.randint(-100,100,size=(4,5))
array_df = pd.DataFrame(array)
array_df
# Out:
#     0   1   2   3   4
# 0 -14  28  46  25  29
# 1 -48  71  59  97  59
# 2 -33  82  83  22  44
# 3 -63 -77 -32  15  -3

# %%
array = np.array(array_df)
array
# Out:
# array([[-14,  28,  46,  25,  29],
#        [-48,  71,  59,  97,  59],
#        [-33,  82,  83,  22,  44],
#        [-63, -77, -32,  15,  -3]])

# %% [markdown]
# 🌟 Exercise 10 : Basic Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.plot(array_df)
plt.title("Line Plot")
plt.xlabel("time")
plt.ylabel("numbers")
plt.grid(True)
plt.show()
