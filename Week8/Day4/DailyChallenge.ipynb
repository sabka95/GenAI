# %% [markdown]
# # ***2. Taxonomie des défis (hiérarchie des catégories)***
# ## **1. Comprendre les LLM**
#
# Compréhension du fonctionnement interne
#
# Interprétation des réponses du modèle
#
# Limites et comportements imprévus
#
# ## **2. Construction de requêtes (prompting)**
#
# Techniques de prompt engineering
#
# Adaptation à des tâches spécifiques
#
# Prompt chaining et structuration
#
# ## **3. Évaluation**
#
# Évaluation des performances (subjective vs objective)
#
# Outils et métriques
#
# Benchmarks manquants ou inadéquats
#
# ## **4. Données**
#
# Collecte et nettoyage de données
#
# Alignement des données d'entrée/sortie
#
# Étiquetage et annotation
#
# ## **5. Déploiement**
#
# Intégration dans des pipelines/applications
#
# Scalabilité
#
# Coût et latence
#
# ## **6. Sécurité et éthique**
#
# Contenu toxique
#
# Fuites d’informations sensibles
#
# Biais algorithmiques
#
# ## **7. Outils et plateformes**
#
# Limitations des interfaces API
#
# Documentation insuffisante
#
# Manque d’exemples ou SDK

# %% [markdown]
# ### 1. Quelles sont les décisions clés de conception prises dans leur méthodologie empirique ?
#
# - **Source des données** : Les auteurs ont extrait 1 114 posts sur Stack Overflow et 1 224 issues GitHub liés aux LLMs (comme OpenAI, Hugging Face, etc.).
# - **Méthodologie hybride** : Une approche inductive (grounded theory) a été utilisée pour construire une taxonomie des problèmes rencontrés.
# - **Sélection guidée par l’usage** : Les auteurs ont filtré les posts selon des critères comme la popularité (votes, commentaires), la clarté, et le fait qu'ils illustrent des problèmes concrets.
# - **Itération** : La taxonomie a été raffinée au fil de plusieurs cycles de codage avec retour utilisateur (co-codage, discussion entre chercheurs).
#
# ### 2. Comment les auteurs ont-ils assuré la validité et la fiabilité de leur procédure de codage ?
#
# - **Codage indépendant par deux chercheurs** : Chaque post a été codé indépendamment pour réduire le biais individuel.
# - **Mesure d’accord inter-annotateurs** : Le kappa de Cohen a été utilisé pour quantifier la fiabilité du codage.
# - **Résolution collaborative des conflits** : Les désaccords ont été résolus par discussion jusqu’à consensus.
# - **Validation externe** : La taxonomie finale a été revue avec d'autres chercheurs et experts.
#
# ### 3. Quels types de défis dominent le développement des LLMs, selon les données ?
#
# - **Prompt Engineering** : C’est l’un des défis les plus fréquemment discutés, notamment la formulation efficace de prompts.
# - **Compréhension des modèles** : Les développeurs sont souvent perdus face aux réponses imprévisibles des modèles.
# - **Évaluation** : Manque de méthodes objectives et reproductibles pour évaluer les performances des modèles.
# - **Limitations des plateformes** : Problèmes liés aux API (taux limites, manque de documentation, etc.).
#
# ### 4. Quelles implications ces défis ont-ils pour la conception des plateformes ou API LLM ?
#
# - **Besoin de meilleures interfaces** : Des outils de débogage ou de visualisation des réponses seraient utiles.
# - **Standardisation des évaluations** : Fournir des benchmarks intégrés dans les plateformes pour faciliter la validation.
# - **Documentation + cas d’usage** : Nécessité de guides plus riches, y compris pour des tâches complexes.
# - **Personnalisation du comportement des modèles** : Les API devraient permettre plus de contrôle sur la sortie générée.
#
# ### 5. Propositions originales de ressources/outils communautaires
#
# #### 📌 Outil 1 : PromptLab — Un environnement interactif de test de prompts
#
# - Interface low-code/no-code pour tester, versionner et comparer différents prompts.
# - Intégration avec des métriques de qualité automatisées (comme perplexité ou diversité).
# - Système de partage communautaire avec notation des prompts efficaces.
#
# #### 🧠 Outil 2 : LLM Error Explainer — Débogueur intelligent de réponses
#
# - Outil qui analyse une réponse LLM "inattendue" et propose des raisons possibles (ex. : ambiguïté du prompt, longueur de contexte…).
# - Suggestions automatiques de reformulation du prompt.
# - Historique visuel des essais pour voir l’évolution des performances.
